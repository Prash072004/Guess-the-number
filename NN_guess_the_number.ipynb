# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import  mnist

# %%
((x_train, y_train), (x_test, y_test)) = mnist.load_data()

# %%
#x_train
#x_test

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape = (28, 28)),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 10, validation_data = (x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2606 - accuracy: 0.9263 - val_loss: 0.1416 - val_accuracy: 0.9581
# Epoch 2/10
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1172 - accuracy: 0.9649 - val_loss: 0.1008 - val_accuracy: 0.9693
# Epoch 3/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0810 - accuracy: 0.9757 - val_loss: 0.0849 - val_accuracy: 0.9743
# Epoch 4/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0595 - accuracy: 0.9821 - val_loss: 0.0779 - val_accuracy: 0.9761
# Epoch 5/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0467 - accuracy: 0.9854 - val_loss: 0.0750 - val_accuracy: 0.9779
# Epoch 6/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0358 - accuracy: 0.9891 - val_loss: 0.0759 - val_accuracy: 0.9776
# Epoch 7/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0292 - accuracy: 0.9912 - val_loss: 0.0739 - val_accuracy: 0.9782
# Epoch 8/10
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 0.0789 - val_accuracy: 0.9775
# Epoch 9/10
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.0815 - val_accuracy: 0.9773
# Epoch 10/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0155 - accuracy: 0.9956 - val_loss: 0.0812 - val_accuracy: 0.9772

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_acc}')
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0812 - accuracy: 0.9772
# Test accuracy: 0.9771999716758728

# %%
plt.imshow(x_test[5000], cmap = 'gray')

# %%
Prediction = model.predict(np.expand_dims(x_test[5000], axis = 0))
print('predicted value: ', np.argmax(Prediction))
# Out:
# 1/1 [==============================] - 0s 42ms/step
# predicted value:  3
